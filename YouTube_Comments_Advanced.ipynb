# %%
dev = "AIzaSyCkp-pQldSBUnTJOt6gRyrx1ktx-dPJfo4"

# %% [markdown]
# ## Pull All Comments

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="haycJYB3piQ",
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="haycJYB3piQ", maxResults=100000, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10661 entries, 0 to 10660
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      10661 non-null  object
#  1   updated_at  10661 non-null  object
#  2   like_count  10661 non-null  int64
#  3   text        10661 non-null  object
#  4   public      10661 non-null  bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 343.7+ KB

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'wlwvqlt7jSwBJvR55XkxG68OT_0',
#  'id': 'Ugz6nyFIeSy8_z-4Y3B4AaABAg',
#  'snippet': {'channelId': 'UCmTM_hPCeckqN3cPWtYZZcg',
#   'videoId': 'haycJYB3piQ',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'j_6tmolyPSJMd1haOJN3pxJpCjw',
#    'id': 'Ugz6nyFIeSy8_z-4Y3B4AaABAg',
#    'snippet': {'channelId': 'UCmTM_hPCeckqN3cPWtYZZcg',
#     'videoId': 'haycJYB3piQ',
#     'textDisplay': '❤❤',
#     'textOriginal': '❤❤',
#     'authorDisplayName': '@3tetratedto3',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/KcbF2Us3DpBw4Aa0X3la8KsaB5gSlF9ZG5Gbd1s0JEShJE4hTDRYE6mm0p5-BzCi-SSugLSx=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@3tetratedto3',
#     'authorChannelId': {'value': 'UCZNjgIL2suf9SLPmxGAPC2w'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2024-06-04T13:45:29Z',
#     'updatedAt': '2024-06-04T13:45:29Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %%
df.head(10)
# Out:
#                  author            updated_at  like_count  \
# 0       @knockknock4337  2024-09-21T08:25:48Z           0
# 1  @sweepingtechenglish  2024-09-20T02:09:14Z           0
# 2           @arun.d2404  2024-09-13T18:39:05Z           0
# 3     @LuckySingh-kk4ow  2024-09-11T04:54:17Z           0
# 4    @zeeshanposwal1002  2024-09-02T18:03:47Z           0
# 5           @ayanpal719  2024-08-12T01:42:48Z           1
# 6    @AnshulKumar-l6s4x  2024-07-28T07:37:40Z           1
# 7         @nawabrahman7  2024-07-19T13:56:05Z           0
# 8               @amt202  2024-07-10T15:41:06Z           1
# 9               @amt202  2024-07-10T15:40:29Z           0
#
#                                                 text  public
# 0                         Akhilesh yadav zindabad ❤❤    True
# 1  I am from srinagar kashmir and this is the bes...    True
# 2                                        TamilNadu 🥰    True
# 3  Now INDI_CHOR will not say EVM is hacked, you ...    True
# 4           Iam from Pakistan. Very intresting vlog.    True
# 5  These people like dekhbhakt the dog follower a...    True
# 6           Sare k sare exit poll galat sabit hue😂😂😂    True
# 7                I from west bengal ❤ didi hamari hi    True
# 8  Check what INDi alliance is doing in West Beng...    True
# 9   https://youtu.be/HltU5zNIrwM?si=1p-txOb9eOugbG-H    True

# %% [markdown]
# ## Sort by Likes and Get Top 10

# %%
df.sort_values(by='like_count', ascending=False)[0:10]
# Out:
#                    author            updated_at  like_count  \
# 10171       @Onlytruth4UM  2024-06-04T13:48:32Z       32208
# 10658           @MAMFacts  2024-06-04T13:45:16Z       13005
# 8703         @yelhoumee09  2024-06-04T14:14:21Z        6105
# 10529   @hassanparwez4291  2024-06-04T13:45:39Z        4038
# 6370   @aditibhardwaj6405  2024-06-04T14:50:24Z        3611
# 10290        @Hashitjadav  2024-06-04T13:46:42Z        3345
# 10321           @hehe2176  2024-06-04T13:46:20Z        3177
# 6707   @deepakkumar-zi6pm  2024-06-04T14:43:14Z        2649
# 6269        @riyamattm845  2024-06-04T14:52:01Z        2632
# 6074             @0autumn  2024-06-04T14:56:08Z        2500
#
#                                                     text  public
# 10171  Dhruv Rathee ke Videos ka asar hua hai is elec...    True
# 10658  all eyes 👀 on nitish kumar& chandra babu 🤣😂\nE...    True
# 8703   I'm in disbelief. BJP is humiliated. The UP st...    True
# 10529  Jaldi jaldi comments me 400 likh deta hu like ...    True
# 6370   Asli khela to ayodhya ke logo ne khelaa👏🏻👏🏻, m...    True
# 10290  Dhruv rathee,ravish kumar, akash Banerjee and ...    True
# 10321  Finally people started to wake up.. Much respe...    True
# 6707   ...\n\n\nThis is a very funny election\n1) BJP...    True
# 6269   I am from Manipur which have only two seat but...    True
# 6074                    We threw out BJP from Ladakh 🙂💪🏼    True

# %% [markdown]
# #Pull all Comments for Multiple Videos

# %% [markdown]
# ## 1. Get Comments Function

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)


def getcomments(video):
  request = youtube.commentThreads().list(
      part="snippet",
      videoId=video,
      maxResults=100
  )

  comments = []

  # Execute the request.
  response = request.execute()

  # Get the comments from the response.
  for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  while (1 == 1):
    try:
     nextPageToken = response['nextPageToken']
    except KeyError:
     break
    nextPageToken = response['nextPageToken']
    # Create a new request object with the next page token.
    nextRequest = youtube.commentThreads().list(part="snippet", videoId=video, maxResults=100, pageToken=nextPageToken)
    # Execute the next request.
    response = nextRequest.execute()
    # Get the comments from the next response.
    for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  df2 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','video_id','public'])
  return df2

# %%
df = getcomments('haycJYB3piQ')
df
# Out:
#                      author            updated_at  like_count  \
# 0           @knockknock4337  2024-09-21T08:25:48Z           0
# 1      @sweepingtechenglish  2024-09-20T02:09:14Z           0
# 2               @arun.d2404  2024-09-13T18:39:05Z           0
# 3         @LuckySingh-kk4ow  2024-09-11T04:54:17Z           0
# 4        @zeeshanposwal1002  2024-09-02T18:03:47Z           0
# ...                     ...                   ...         ...
# 10656    @OfficialMithun981  2024-06-04T13:45:18Z           0
# 10657       @hassanraza7536  2024-06-04T13:45:18Z           0
# 10658             @MAMFacts  2024-06-04T13:45:16Z       13005
# 10659               @galiu7  2024-06-04T13:45:16Z           0
# 10660          @ashok......  2024-06-04T13:45:14Z           0
#
#                                                     text     video_id  public
# 0                             Akhilesh yadav zindabad ❤❤  haycJYB3piQ    True
# 1      I am from srinagar kashmir and this is the bes...  haycJYB3piQ    True
# 2                                            TamilNadu 🥰  haycJYB3piQ    True
# 3      Now INDI_CHOR will not say EVM is hacked, you ...  haycJYB3piQ    True
# 4               Iam from Pakistan. Very intresting vlog.  haycJYB3piQ    True
# ...                                                  ...          ...     ...
# 10656                                               😂😂😂😂  haycJYB3piQ    True
# 10657                                 First one to watch  haycJYB3piQ    True
# 10658  all eyes 👀 on nitish kumar& chandra babu 🤣😂\nE...  haycJYB3piQ    True
# 10659                                           Hi sir ❤  haycJYB3piQ    True
# 10660                                              First  haycJYB3piQ    True
#
# [10661 rows x 6 columns]

# %% [markdown]
# ## 2. For Loop for List of IDs

# %%
df = pd.DataFrame()
for i in ['JCKWQcLd6-o','Bh9aPzyFP1Q','tBPBfBdpMDc','bzbsJGMVHxQ']:
  df2 = getcomments(i)
  df = pd.concat([df, df2])

# %%
df
# Out:
#                        author            updated_at  like_count  \
# 0         @mohdzubairkhan3521  2024-10-05T04:05:47Z           0
# 1                @girishm8742  2024-08-09T18:11:21Z           0
# 2         @sarthakjaiswal5864  2024-07-01T03:39:18Z           0
# 3             @RKCAgainGaming  2024-06-27T08:03:18Z           0
# 4       @navinbhaivachhani848  2024-06-22T05:05:53Z           0
# ...                       ...                   ...         ...
# 281770   @ShubhamPandey-fo1vj  2024-05-12T16:23:18Z           5
# 281771    @shobhagorghate3571  2024-05-12T16:23:16Z          81
# 281772          @Pankaj00987i  2024-05-12T16:23:16Z           3
# 281773         @SkSukur-gd1kx  2024-05-12T16:23:13Z          15
# 281774             @Kyojuro71  2024-05-12T16:23:12Z         143
#
#                                                      text     video_id  public
# 0       Ravish kumar Sar ji Adab Sar Aap Pen pensil ka...  JCKWQcLd6-o    True
# 1                                               Hi brokar  JCKWQcLd6-o    True
# 2          22:20 Ravish ji is baat ko pahle se hi jaante.  JCKWQcLd6-o    True
# 3                                            Chal jhuthae  JCKWQcLd6-o    True
# 4        https://youtu.be/6bozyHzbIys?si=4JvRt5DB8ba6Hz-a  JCKWQcLd6-o    True
# ...                                                   ...          ...     ...
# 281770  Lol I am first one to watch this video after d...  bzbsJGMVHxQ    True
# 281771              **Dhruv Rathee Modern Bhagat Singh❤❤❤  bzbsJGMVHxQ    True
# 281772                                        1st comment  bzbsJGMVHxQ    True
# 281773                                             Love u  bzbsJGMVHxQ    True
# 281774  Bhailog Kal Sablog Soch Smajh kar Vote Dena Au...  bzbsJGMVHxQ    True
#
# [520344 rows x 6 columns]

# %%
df['video_id'].value_counts()
# Out:
# video_id
# bzbsJGMVHxQ    281775
# tBPBfBdpMDc    213590
# JCKWQcLd6-o     17504
# Bh9aPzyFP1Q      7475
# Name: count, dtype: int64

# %%
df.to_excel('output.xlsx', index=False)

print("DataFrame has been exported to 'output.xlsx'")
# Out:
# DataFrame has been exported to 'output.xlsx'
